# %%
import numpy as np
import pandas as pd

# %%
student_data=pd.read_csv('StudentsPerformance.csv')

# %%
student_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                         NaN      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                         NaN      standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %%
student_data.describe()
# Out:
#          mathscore  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     65.969000      69.169000      68.054000
# std      15.310338      14.600192      15.195657
# min       0.000000      17.000000      10.000000
# 25%      56.750000      59.000000      57.750000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
student_data.drop(['lunch','test preparation course'],axis=1, inplace=False)
# Out:
#      gender race/ethnicity parental level of education  mathscore  \
# 0    female        group B           bachelor's degree         72
# 1    female        group C                         NaN         69
# 2    female        group B             master's degree         90
# 3      male        group A          associate's degree         47
# 4      male        group C                         NaN         76
# 5    female        group B          associate's degree         71
# 6    female        group B                         NaN         88
# 7      male        group B                         NaN         40
# 8      male        group D                 high school         64
# 9    female        group B                 high school         38
# 10     male        group C          associate's degree         58
# 11     male        group D          associate's degree         40
# 12   female        group B                 high school         65
# 13     male        group A                         NaN         78
# 14   female        group A             master's degree         50
# 15   female        group C            some high school         69
# 16     male        group C                 high school         88
# 17   female        group B            some high school         18
# 18     male        group C             master's degree         46
# 19   female        group C          associate's degree         54
# 20     male        group D                 high school         66
# 21   female        group B                         NaN         65
# 22     male        group D                         NaN         44
# 23   female        group C            some high school         69
# 24     male        group D           bachelor's degree         74
# 25     male        group A             master's degree         73
# 26     male        group B                         NaN         69
# 27   female        group C           bachelor's degree         67
# 28     male        group C                 high school         70
# 29   female        group D             master's degree         62
# ..      ...            ...                         ...        ...
# 970  female        group D           bachelor's degree         89
# 971    male        group C            some high school         78
# 972  female        group A                 high school         53
# 973  female        group D                         NaN         49
# 974  female        group A                         NaN         54
# 975  female        group C                         NaN         64
# 976    male        group B                         NaN         60
# 977    male        group C          associate's degree         62
# 978    male        group D                 high school         55
# 979  female        group C          associate's degree         91
# 980  female        group B                 high school          8
# 981    male        group D            some high school         81
# 982    male        group B            some high school         79
# 983  female        group A                         NaN         78
# 984  female        group C            some high school         74
# 985    male        group A                 high school         57
# 986  female        group C          associate's degree         40
# 987    male        group E            some high school         81
# 988  female        group A            some high school         44
# 989  female        group D                         NaN         67
# 990    male        group E                 high school         86
# 991  female        group B            some high school         65
# 992  female        group D          associate's degree         55
# 993  female        group D           bachelor's degree         62
# 994    male        group A                 high school         63
# 995  female        group E             master's degree         88
# 996    male        group C                 high school         62
# 997  female        group C                 high school         59
# 998  female        group D                         NaN         68
# 999  female        group D                         NaN         77
#
#      reading score  writing score
# 0               72             74
# 1               90             88
# 2               95             93
# 3               57             44
# 4               78             75
# 5               83             78
# 6               95             92
# 7               43             39
# 8               64             67
# 9               60             50
# 10              54             52
# 11              52             43
# 12              81             73
# 13              72             70
# 14              53             58
# 15              75             78
# 16              89             86
# 17              32             28
# 18              42             46
# 19              58             61
# 20              69             63
# 21              75             70
# 22              54             53
# 23              73             73
# 24              71             80
# 25              74             72
# 26              54             55
# 27              69             75
# 28              70             65
# 29              70             75
# ..             ...            ...
# 970            100            100
# 971             72             69
# 972             50             60
# 973             65             61
# 974             63             67
# 975             82             77
# 976             62             60
# 977             65             58
# 978             41             48
# 979             95             94
# 980             24             23
# 981             78             78
# 982             85             86
# 983             87             91
# 984             75             82
# 985             51             54
# 986             59             51
# 987             75             76
# 988             45             45
# 989             86             83
# 990             81             75
# 991             82             78
# 992             76             76
# 993             72             74
# 994             63             62
# 995             99             95
# 996             55             55
# 997             71             65
# 998             78             77
# 999             86             86
#
# [1000 rows x 6 columns]

# %%
student_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                         NaN      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                         NaN      standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %%
student_data["parental level of education"]= student_data["parental level of education"].fillna("school")

# %%
student_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                      school      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                      school      standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %%
student_data["race/ethnicity"]=student_data["race/ethnicity"].map({"group A":"Asian Students", "group B":"African Students","group C":"Afro-American Students","group D":"American Students","group E":"European Students"})

# %%
student_data.head()
# Out:
#    gender          race/ethnicity parental level of education         lunch  \
# 0  female        African Students           bachelor's degree      standard
# 1  female  Afro-American Students                      school      standard
# 2  female        African Students             master's degree      standard
# 3    male          Asian Students          associate's degree  free/reduced
# 4    male  Afro-American Students                      school      standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %%
print(pd.crosstab(student_data["gender"],student_data["test preparation course"]))
# Out:
# test preparation course  completed  none
# gender
# female                         184   334
# male                           174   308

# %%
student_data
# Out:
#      gender          race/ethnicity parental level of education         lunch  \
# 0    female        African Students           bachelor's degree      standard
# 1    female  Afro-American Students                      school      standard
# 2    female        African Students             master's degree      standard
# 3      male          Asian Students          associate's degree  free/reduced
# 4      male  Afro-American Students                      school      standard
# 5    female        African Students          associate's degree      standard
# 6    female        African Students                      school      standard
# 7      male        African Students                      school  free/reduced
# 8      male       American Students                 high school  free/reduced
# 9    female        African Students                 high school  free/reduced
# 10     male  Afro-American Students          associate's degree      standard
# 11     male       American Students          associate's degree      standard
# 12   female        African Students                 high school      standard
# 13     male          Asian Students                      school      standard
# 14   female          Asian Students             master's degree      standard
# 15   female  Afro-American Students            some high school      standard
# 16     male  Afro-American Students                 high school      standard
# 17   female        African Students            some high school  free/reduced
# 18     male  Afro-American Students             master's degree  free/reduced
# 19   female  Afro-American Students          associate's degree  free/reduced
# 20     male       American Students                 high school      standard
# 21   female        African Students                      school  free/reduced
# 22     male       American Students                      school      standard
# 23   female  Afro-American Students            some high school      standard
# 24     male       American Students           bachelor's degree  free/reduced
# 25     male          Asian Students             master's degree  free/reduced
# 26     male        African Students                      school      standard
# 27   female  Afro-American Students           bachelor's degree      standard
# 28     male  Afro-American Students                 high school      standard
# 29   female       American Students             master's degree      standard
# ..      ...                     ...                         ...           ...
# 970  female       American Students           bachelor's degree      standard
# 971    male  Afro-American Students            some high school      standard
# 972  female          Asian Students                 high school  free/reduced
# 973  female       American Students                      school  free/reduced
# 974  female          Asian Students                      school      standard
# 975  female  Afro-American Students                      school      standard
# 976    male        African Students                      school  free/reduced
# 977    male  Afro-American Students          associate's degree      standard
# 978    male       American Students                 high school      standard
# 979  female  Afro-American Students          associate's degree      standard
# 980  female        African Students                 high school  free/reduced
# 981    male       American Students            some high school      standard
# 982    male        African Students            some high school      standard
# 983  female          Asian Students                      school      standard
# 984  female  Afro-American Students            some high school      standard
# 985    male          Asian Students                 high school      standard
# 986  female  Afro-American Students          associate's degree      standard
# 987    male       European Students            some high school      standard
# 988  female          Asian Students            some high school  free/reduced
# 989  female       American Students                      school  free/reduced
# 990    male       European Students                 high school  free/reduced
# 991  female        African Students            some high school      standard
# 992  female       American Students          associate's degree  free/reduced
# 993  female       American Students           bachelor's degree  free/reduced
# 994    male          Asian Students                 high school      standard
# 995  female       European Students             master's degree      standard
# 996    male  Afro-American Students                 high school  free/reduced
# 997  female  Afro-American Students                 high school  free/reduced
# 998  female       American Students                      school      standard
# 999  female       American Students                      school  free/reduced
#
#     test preparation course  mathscore  reading score  writing score
# 0                      none         72             72             74
# 1                 completed         69             90             88
# 2                      none         90             95             93
# 3                      none         47             57             44
# 4                      none         76             78             75
# 5                      none         71             83             78
# 6                 completed         88             95             92
# 7                      none         40             43             39
# 8                 completed         64             64             67
# 9                      none         38             60             50
# 10                     none         58             54             52
# 11                     none         40             52             43
# 12                     none         65             81             73
# 13                completed         78             72             70
# 14                     none         50             53             58
# 15                     none         69             75             78
# 16                     none         88             89             86
# 17                     none         18             32             28
# 18                completed         46             42             46
# 19                     none         54             58             61
# 20                     none         66             69             63
# 21                completed         65             75             70
# 22                     none         44             54             53
# 23                     none         69             73             73
# 24                completed         74             71             80
# 25                     none         73             74             72
# 26                     none         69             54             55
# 27                     none         67             69             75
# 28                     none         70             70             65
# 29                     none         62             70             75
# ..                      ...        ...            ...            ...
# 970                    none         89            100            100
# 971               completed         78             72             69
# 972               completed         53             50             60
# 973                    none         49             65             61
# 974                    none         54             63             67
# 975               completed         64             82             77
# 976               completed         60             62             60
# 977                    none         62             65             58
# 978               completed         55             41             48
# 979                    none         91             95             94
# 980                    none          8             24             23
# 981                    none         81             78             78
# 982               completed         79             85             86
# 983               completed         78             87             91
# 984                    none         74             75             82
# 985                    none         57             51             54
# 986                    none         40             59             51
# 987               completed         81             75             76
# 988                    none         44             45             45
# 989               completed         67             86             83
# 990               completed         86             81             75
# 991               completed         65             82             78
# 992                    none         55             76             76
# 993                    none         62             72             74
# 994                    none         63             63             62
# 995               completed         88             99             95
# 996                    none         62             55             55
# 997               completed         59             71             65
# 998               completed         68             78             77
# 999                    none         77             86             86
#
# [1000 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax=sns.countplot(x = 'gender', hue = 'test preparation course', palette = 'Set2', data = student_data)
ax.set(title = 'Test prep course', xlabel = 'Gender', ylabel='Total Count')
plt.show()

# %%
pd.crosstab(student_data["gender"],student_data["race/ethnicity"])
# Out:
# race/ethnicity  African Students  Afro-American Students  American Students  \
# gender
# female                       104                     180                129
# male                          86                     139                133
#
# race/ethnicity  Asian Students  European Students
# gender
# female                      36                 69
# male                        53                 71

# %%
ax2=sns.countplot(x="gender", hue="race/ethnicity", palette='Set1',data=student_data)
ax2.set(title="Group Of Students", xlabel="Gender", ylabel="Total Count")
plt.show()

# %%
student_data.head()
# Out:
#    gender          race/ethnicity parental level of education         lunch  \
# 0  female        African Students           bachelor's degree      standard
# 1  female  Afro-American Students                      school      standard
# 2  female        African Students             master's degree      standard
# 3    male          Asian Students          associate's degree  free/reduced
# 4    male  Afro-American Students                      school      standard
#
#   test preparation course  mathscore  reading score  writing score
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75

# %%
student_data.describe()
# Out:
#          mathscore  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     65.969000      69.169000      68.054000
# std      15.310338      14.600192      15.195657
# min       0.000000      17.000000      10.000000
# 25%      56.750000      59.000000      57.750000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
interval = (0,40,60,75,100)
categories = ['Failed','Second Class','First Class', 'Distinction']
student_data['Math_category'] = pd.cut(student_data.mathscore, interval, labels = categories)
student_data['Read_category']=pd.cut(student_data["reading score"],interval, labels=categories)
student_data['Write_category']=pd.cut(student_data["writing score"],interval,labels=categories)
student_data['Grades']=pd.cut(student_data.mean(axis=1),interval,labels=categories)

# %%
ax=sns.countplot(x='gender',data=student_data,hue='Grades',palette='Set1')\
.set(xlabel=' gender',ylabel='Grades',Title='performance')
plt.show()

# %%
x=sns.countplot(x='test preparation course',data=student_data,hue='gender',palette='Set2')\
.set(xlabel='course',ylabel='pass/fail',Title='graph1')
plt.show()

# %%
ax=sns.countplot(x='race/ethnicity',data=student_data,hue='gender',palette='Set3')\
.set(xlabel='race',ylabel='students',Title='graph2')
plt.show()

# %%
student_data.head()
# Out:
#    gender          race/ethnicity parental level of education         lunch  \
# 0  female        African Students           bachelor's degree      standard
# 1  female  Afro-American Students                      school      standard
# 2  female        African Students             master's degree      standard
# 3    male          Asian Students          associate's degree  free/reduced
# 4    male  Afro-American Students                      school      standard
#
#   test preparation course  mathscore  reading score  writing score  \
# 0                    none         72             72             74
# 1               completed         69             90             88
# 2                    none         90             95             93
# 3                    none         47             57             44
# 4                    none         76             78             75
#
#   Math_category Read_category Write_category
# 0   First Class   First Class    First Class
# 1   First Class   Distinction    Distinction
# 2   Distinction   Distinction    Distinction
# 3  Second Class  Second Class   Second Class
# 4   Distinction   Distinction    First Class

# %%
pd.crosstab(student_data.gender,student_data.Read_category)
# Out:
# Read_category  Failed  Second Class  First Class  Distinction
# gender
# female             12            86          195          225
# male               15           162          186          119

# %%
student_data["Math_category"].describe()
# Out:
# count             999
# unique              4
# top       First Class
# freq              386
# Name: Math_category, dtype: object

# %%
student_data.Math_category.value_counts()
# Out:
# First Class     386
# Second Class    289
# Distinction     273
# Failed           51
# Name: Math_category, dtype: int64

# %%
student_data.Read_category.value_counts()
# Out:
# First Class     381
# Distinction     344
# Second Class    248
# Failed           27
# Name: Read_category, dtype: int64

# %%
student_data.Write_category.value_counts()
# Out:
# First Class     371
# Distinction     328
# Second Class    266
# Failed           35
# Name: Write_category, dtype: int64

# %%
sns.countplot(x="gender", hue="Grades", palette='Set1',data=student_data)
